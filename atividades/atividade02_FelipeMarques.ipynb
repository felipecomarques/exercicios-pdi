# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
imagem = np.array(cv2.imread('drive/MyDrive/lena.png', cv2.IMREAD_GRAYSCALE))
cv2_imshow(imagem)
print(imagem)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F97E7902D50>
# [[161 161 161 ... 168 166 151]
#  [162 161 161 ... 183 173 140]
#  [161 161 160 ... 164 147 113]
#  ...
#  [ 49  53  55 ...  80  90  94]
#  [ 48  51  53 ...  93  99 100]
#  [ 46  48  50 ... 102 106 105]]

# %%
segmentar = imagem[120:150, 1:256]
cv2_imshow(segmentar)
print (segmentar)
type (segmentar)
# Out:
# <PIL.Image.Image image mode=L size=255x30 at 0x7F97E7B0E5D0>
# [[103 103 102 ... 150 153 156]
#  [101 101 100 ... 144 146 148]
#  [100 100  99 ... 139 139 139]
#  ...
#  [ 88  89  84 ... 198 199 200]
#  [ 84  84  80 ... 202 203 204]
#  [ 82  81  77 ... 204 205 205]]
# numpy.ndarray

# %%
cv2.imwrite('drive/MyDrive/lena_segmentada.png', segmentar)
# Out:
# True
