# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
A = cv2.imread('drive/MyDrive/bleh.png')

# %%
print(A)
# Out:
# [[[105  73  68]
#   [107  75  70]
#   [107  76  71]
#   ...
#   [131 107  87]
#   [136 112  93]
#   [141 117  98]]
#
#  [[102  73  70]
#   [104  74  70]
#   [105  75  69]
#   ...
#   [131 105  88]
#   [135 109  91]
#   [140 115  96]]
#
#  [[101  73  72]
#   [103  74  72]
#   [105  75  71]
#   ...
#   [130 104  87]
#   [134 107  90]
#   [138 112  95]]
#
#  ...
#
#  [[ 50  31  28]
#   [ 49  29  26]
#   [ 51  30  27]
#   ...
#   [131 105 104]
#   [129 103 102]
#   [127 101 100]]
#
#  [[ 48  30  26]
#   [ 49  30  26]
#   [ 52  31  27]
#   ...
#   [131 105 104]
#   [129 103 102]
#   [127 101 100]]
#
#  [[ 49  31  26]
#   [ 50  31  26]
#   [ 52  31  27]
#   ...
#   [130 104 104]
#   [129 103 102]
#   [127 101 101]]]

# %%
cv2_imshow(A)
# Out:
# <PIL.Image.Image image mode=RGB size=443x321 at 0x7FECCB6AA410>

# %%
Agrey = cv2.imread('drive/MyDrive/bleh.png', cv2.IMREAD_GRAYSCALE)
cv2_imshow(Agrey)
# Out:
# <PIL.Image.Image image mode=L size=443x321 at 0x7FECCB6008D0>

# %%
cv2.imwrite('drive/MyDrive/bleh_cinza.png', Agrey)
# Out:
# True
